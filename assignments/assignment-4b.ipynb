# %% [markdown]
# ## Module 4: Cleaning data with pandas
# ## Weekly Assignment 4B
# ### Brandan Owens and Loan Pham

# %% [markdown]
# ### Q.1 Download the dataset "adult_income_data.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# (a) read in the dataset with pd.read_csv. Show the first 8 records, what’s wrong with the process of importing the dataset.
ad = pd.read_csv("../dataFiles/adult_income_data.csv")
ad.head(8)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8ca5a4f552e1> in <module>
#       1 # (a) read in the dataset with pd.read_csv. Show the first 8 records, what’s wrong with the process of importing the dataset.
# ----> 2 ad = pd.read_csv("adult_income_data.csv")
#       3 ad.head(8)
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\miniconda3\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~\miniconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'adult_income_data.csv'

# %%
# (b) read the dataset again and bear in mind that the dataset has no header (use header = None).
ad = pd.read_csv("../dataFiles/adult_income_data.csv", header = None)
ad.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7        8     9   10  11              12  \
# 0        Adm-clerical   Not-in-family     Male  2174   0  40   United-States
# 1     Exec-managerial         Husband     Male     0   0  13   United-States
# 2   Handlers-cleaners   Not-in-family     Male     0   0  40   United-States
# 3   Handlers-cleaners         Husband     Male     0   0  40   United-States
# 4      Prof-specialty            Wife   Female     0   0  40            Cuba
#
#        13
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %%
# (c) name the columns. Refer to the "adult_income_names.txt"

#header_names = ['age','workclass', 'fnlwgt','education','education-num',
                  # 'marital-status','occupation','relationship','sex','capital-gain','capital-loss',
                  # 'hours-per-week','native-country','wage_category']
#ad1 = pd.read_csv("adult_income_data.csv", header = None, skiprows = 1, names = header_names)

names=[]
with open("../dataFiles/adult_income_names.txt","r") as f:
    for line in f:
        f.readline()
        var = line.split(":")[0]
        names.append(var)
names
ad1.columns = names
ad1.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship      sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband     Male
# 1             Divorced   Handlers-cleaners   Not-in-family     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country wage_category
# 0             0             0              13   United-States         <=50K
# 1             0             0              40   United-States         <=50K
# 2             0             0              40   United-States         <=50K
# 3             0             0              40            Cuba         <=50K
# 4             0             0              40   United-States         <=50K

# %%
# (d) get the statistical summary of the dataset.
ad1.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# (e) Create a DataFrame with only age, education, and occupation

ad2 = ad1[['age','education','occupation']]
ad2.head()
# Out:
#      age   education        occupation
# 7     31     Masters    Prof-specialty
# 8     42   Bachelors   Exec-managerial
# 83    44     HS-grad      Craft-repair
# 100   44   Bachelors   Exec-managerial
# 104   32     HS-grad      Craft-repair

# %%
# (g) Find the number of people who are aged between 30 and 50

ad2 = ad2[ad1['age'].between(30, 50)]
ad2.head()
# Out:
#      age   education        occupation
# 7     31     Masters    Prof-specialty
# 8     42   Bachelors   Exec-managerial
# 83    44     HS-grad      Craft-repair
# 100   44   Bachelors   Exec-managerial
# 104   32     HS-grad      Craft-repair

# %%
# (h) Find the number of people who are aged between 30 and 50, and made positive capital gain.

ad3 = ad1[['age','education','occupation','capital-gain']]
ad3 = ad3[(ad1['age'] >= 30) & (ad3['age'] <= 50)  & (ad3['capital-gain'] > 0)]
ad3.head()
# Out:
#      age   education        occupation  capital-gain
# 7     31     Masters    Prof-specialty         14084
# 8     42   Bachelors   Exec-managerial          5178
# 83    44     HS-grad      Craft-repair         14344
# 100   44   Bachelors   Exec-managerial         15024
# 104   32     HS-grad      Craft-repair          7688

# %%
# (i)  group by "occupation", show the median age of each group.

grouped = ad2.groupby('occupation')['age'].median()
grouped
# Out:
# occupation
#  ?                    36.0
#  Adm-clerical         40.0
#  Craft-repair         40.0
#  Exec-managerial      41.0
#  Farming-fishing      41.0
#  Handlers-cleaners    38.0
#  Machine-op-inspct    40.0
#  Other-service        39.0
#  Priv-house-serv      45.5
#  Prof-specialty       41.0
#  Protective-serv      37.0
#  Sales                40.0
#  Tech-support         40.0
#  Transport-moving     41.0
# Name: age, dtype: float64

# %%
# (j)  use the following codes to create two dataframes
df1 = data_income[['age', 'workclass', 'occupation']].sample(5,random_state=101)
df2 = data_income[['education','occupation']].sample(5,random_state=101)

# merge df1 with df2. The key is  'occupation'
# data_income.merge(df1, df2, on="occupation")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-153-a7f6eea12b72> in <module>
#       1 # (j)  use the following codes to create two dataframes
# ----> 2 df1 = data_income[['age', 'workclass', 'occupation']].sample(5,random_state=101)
#       3 df2 = data_income[['education','occupation']].sample(5,random_state=101)
#       4 # merge df1 with df2. The key is  'occupation'
#       5 data_income.merge(df1, df2, on="occupation")
#
# NameError: name 'data_income' is not defined

# %%
#Q.2.a Read in dataset 'Energy Indicators.xls'. Exclude the footer & header info, the first two columns and change the labels to reflect ['Country','Energy Supply','Energy Supply per Capita','% Renewable']. Be sure to remove everything but the characters in 'Country'. Rename the following countries ["Republic of Korea":"South Korea","United States of America":"United States","United Kingdom of Great Britain and Northern Ireland":"United Kingdom","China, Hong Kong Special Administrative Region":"Hong Kong","Bolivia (Plurinational State of)":"Bolivia","Switzerland17":"Switzerland"].

# %%
#Q.2.b Load the GDP Data from "world_bank.xlsx". Exclude the header, rename the following countries ["Korea, Rep.":"South Korea","Iran, Islamic Rep.":"Iran","Hong Kong SAR, China":"Hong Kong"]

# %%
#Q.2.c Load the dataset scimagojr.xlsx

# %%
#Q.2.d Join the three datasets, retain only the last 10 years of GDP data and only the top 15 countries by Scimagojr 'Rank'

# %%
#Q.2.e What is the average GDP over the last 10 years for each country?

# %%
#Q.2.f By how much had the GDP changed over the 10-year span for the country with the 6th largest average GDP?

# %%
#Q.2.g Create a new column that is the ration of Self-Citations to Total Citations. What is the maximum value for this new column, and what country has the highest ratio?
