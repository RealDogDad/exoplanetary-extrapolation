# %% [markdown]
# ## Module 4: Cleaning data with pandas
# ## Weekly Assignment 4A
# ### Brandon Owens, Loan Pham

# %% [markdown]
# ### Q.1 Read in the dataset 'Banking_Marketing.csv'

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../dataFiles/Banking_Marketing.csv")
df
# Out:
#          age          job  marital            education  default housing loan  \
# 0       44.0  blue-collar  married             basic.4y  unknown     yes   no
# 1       53.0   technician  married              unknown       no      no   no
# 2       28.0   management   single    university.degree       no     yes   no
# 3       39.0     services  married          high.school       no      no   no
# 4       55.0      retired  married             basic.4y       no     yes   no
# ...      ...          ...      ...                  ...      ...     ...  ...
# 41194  104.0      retired  married          high.school  unknown      no  yes
# 41195    2.0    housemaid  married                Basic  unknown      no    n
# 41196    3.0       admin.   single    university.degree  unknown     yes    y
# 41197    NaN   technician  married  professional.course       no      no    n
# 41198    NaN      student   single          high.school       no      no    n
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0       cellular   aug         thu  ...         1    999         0
# 1       cellular   nov         fri  ...         1    999         0
# 2       cellular   jun         thu  ...         3      6         2
# 3       cellular   apr         fri  ...         2    999         0
# 4       cellular   aug         fri  ...         1      3         1
# ...          ...   ...         ...  ...       ...    ...       ...
# 41194  telephone   jun         thu  ...         1    999         0
# 41195        NaN   may         thu  ...         2    999         0
# 41196        NaN   may         wed  ...         3    999         0
# 41197  telephone   oct         tue  ...         2    999         0
# 41198  telephone   may         fri  ...         4    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0      nonexistent          1.4          93.444          -36.1      4.963
# 1      nonexistent         -0.1          93.200          -42.0      4.021
# 2          success         -1.7          94.055          -39.8      0.729
# 3      nonexistent         -1.8          93.075          -47.1      1.405
# 4          success         -2.9          92.201          -31.4      0.869
# ...            ...          ...             ...            ...        ...
# 41194  nonexistent          1.4          94.465          -41.8      4.866
# 41195  nonexistent          1.1          93.994          -36.4      4.860
# 41196  nonexistent          1.1          93.994          -36.4      4.857
# 41197  nonexistent         -3.4          92.431          -26.9      0.742
# 41198  nonexistent          1.1          93.994          -36.4      4.859
#
#        nr_employed  y
# 0           5228.1  0
# 1           5195.8  0
# 2           4991.6  1
# 3           5099.1  0
# 4           5076.2  1
# ...            ... ..
# 41194       5228.1  0
# 41195       5191.0  0
# 41196       5191.0  0
# 41197       5017.5  0
# 41198       5191.0  0
#
# [41199 rows x 21 columns]

# %%
# (a) show the names of the columns of the dataset

for col in df.columns:
    print(col)
# Out:
# age
# job
# marital
# education
# default
# housing
# loan
# contact
# month
# day_of_week
# duration
# campaign
# pdays
# previous
# poutcome
# emp_var_rate
# cons_price_idx
# cons_conf_idx
# euribor3m
# nr_employed
# y

# %%
# (b) print the basic info of each column using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41199 entries, 0 to 41198
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41197 non-null  float64
#  1   job             41199 non-null  object
#  2   marital         41199 non-null  object
#  3   education       41199 non-null  object
#  4   default         41199 non-null  object
#  5   housing         41199 non-null  object
#  6   loan            41199 non-null  object
#  7   contact         41193 non-null  object
#  8   month           41199 non-null  object
#  9   day_of_week     41199 non-null  object
#  10  duration        41192 non-null  float64
#  11  campaign        41199 non-null  int64
#  12  pdays           41199 non-null  int64
#  13  previous        41199 non-null  int64
#  14  poutcome        41199 non-null  object
#  15  emp_var_rate    41199 non-null  float64
#  16  cons_price_idx  41199 non-null  float64
#  17  cons_conf_idx   41199 non-null  float64
#  18  euribor3m       41199 non-null  float64
#  19  nr_employed     41199 non-null  float64
#  20  y               41199 non-null  int64
# dtypes: float64(7), int64(4), object(10)
# memory usage: 6.6+ MB

# %%
# (c) check any missing values for each variable (column)
df.isnull().any()
# Out:
# age                True
# job               False
# marital           False
# education         False
# default           False
# housing           False
# loan              False
# contact            True
# month             False
# day_of_week       False
# duration           True
# campaign          False
# pdays             False
# previous          False
# poutcome          False
# emp_var_rate      False
# cons_price_idx    False
# cons_conf_idx     False
# euribor3m         False
# nr_employed       False
# y                 False
# dtype: bool

# %%
# (d) drop all the rows with any missing values
df.dropna()
# Out:
#          age          job  marital          education  default housing loan  \
# 0       44.0  blue-collar  married           basic.4y  unknown     yes   no
# 1       53.0   technician  married            unknown       no      no   no
# 2       28.0   management   single  university.degree       no     yes   no
# 3       39.0     services  married        high.school       no      no   no
# 4       55.0      retired  married           basic.4y       no     yes   no
# ...      ...          ...      ...                ...      ...     ...  ...
# 41182   24.0       admin.  married        high.school       no     yes   no
# 41183   59.0      retired  married        high.school  unknown      no  yes
# 41184   31.0    housemaid  married           basic.4y  unknown      no   no
# 41187   25.0      student   single        high.school       no      no   no
# 41194  104.0      retired  married        high.school  unknown      no  yes
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 0       cellular   aug         thu  ...         1    999         0
# 1       cellular   nov         fri  ...         1    999         0
# 2       cellular   jun         thu  ...         3      6         2
# 3       cellular   apr         fri  ...         2    999         0
# 4       cellular   aug         fri  ...         1      3         1
# ...          ...   ...         ...  ...       ...    ...       ...
# 41182   cellular   may         thu  ...         4    999         1
# 41183  telephone   jun         thu  ...         1    999         0
# 41184  telephone   may         thu  ...         2    999         0
# 41187  telephone   may         fri  ...         4    999         0
# 41194  telephone   jun         thu  ...         1    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 0      nonexistent          1.4          93.444          -36.1      4.963
# 1      nonexistent         -0.1          93.200          -42.0      4.021
# 2          success         -1.7          94.055          -39.8      0.729
# 3      nonexistent         -1.8          93.075          -47.1      1.405
# 4          success         -2.9          92.201          -31.4      0.869
# ...            ...          ...             ...            ...        ...
# 41182      failure         -1.8          92.893          -46.2      1.266
# 41183  nonexistent          1.4          94.465          -41.8      4.866
# 41184  nonexistent          1.1          93.994          -36.4      4.860
# 41187  nonexistent          1.1          93.994          -36.4      4.859
# 41194  nonexistent          1.4          94.465          -41.8      4.866
#
#        nr_employed  y
# 0           5228.1  0
# 1           5195.8  0
# 2           4991.6  1
# 3           5099.1  0
# 4           5076.2  1
# ...            ... ..
# 41182       5099.1  0
# 41183       5228.1  0
# 41184       5191.0  0
# 41187       5191.0  0
# 41194       5228.1  0
#
# [41187 rows x 21 columns]

# %%
# (e) do a value count for the variable 'education'
df["education"].value_counts()
# Out:
# university.degree      12170
# high.school             9521
# basic.9y                6045
# professional.course     5244
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Basic                      2
# Name: education, dtype: int64

# %%
# (f)  group the "basic.4y", "basic.9y", and "basic.6y" categories together and call them "basic". Then do the value count for "education" again.
df["education"].replace({"basic.9y":"Basic","basic.6y":"Basic","basic.4y":"Basic"},inplace=True)
df["education"].value_counts()
# Out:
# Basic                  12515
# university.degree      12170
# high.school             9521
# professional.course     5244
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
# (g) get all the columns with non-numeric data. Then create dummy variables for those columns (one-hot encoding).
cols = df.select_dtypes([object]).columns
print(cols)
newDF = pd.get_dummies(df.select_dtypes([object]).columns,dtype=str)
newDF.info()
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   contact      10 non-null     object
#  1   day_of_week  10 non-null     object
#  2   default      10 non-null     object
#  3   education    10 non-null     object
#  4   housing      10 non-null     object
#  5   job          10 non-null     object
#  6   loan         10 non-null     object
#  7   marital      10 non-null     object
#  8   month        10 non-null     object
#  9   poutcome     10 non-null     object
# dtypes: object(10)
# memory usage: 928.0+ bytes

# %% [markdown]
# ## Q.2 Read in “flights.csv”

# %%
fl = pd.read_csv("../dataFiles/flights.csv")
fl
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  850       33.0      AA    1141  N619AA    JFK  MIA
# 3                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 4                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336771            1634        NaN      9E    3393     NaN    JFK  DCA
# 336772            2312        NaN      9E    3525     NaN    LGA  SYR
# 336773            1330        NaN      MQ    3461  N535MQ    LGA  BNA
# 336774            1344        NaN      MQ    3572  N511MQ    LGA  CLE
# 336775            1020        NaN      MQ    3531  N839MQ    LGA  RDU
#
#         air_time  distance  hour  minute             time_hour
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 2          160.0      1089     5      40  2013-01-01T10:00:00Z
# 3          183.0      1576     5      45  2013-01-01T10:00:00Z
# 4          116.0       762     6       0  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336771       NaN       213    14      55  2013-09-30T18:00:00Z
# 336772       NaN       198    22       0  2013-10-01T02:00:00Z
# 336773       NaN       764    12      10  2013-09-30T16:00:00Z
# 336774       NaN       419    11      59  2013-09-30T15:00:00Z
# 336775       NaN       431     8      40  2013-09-30T12:00:00Z
#
# [336776 rows x 19 columns]

# %%
# (a) Find all flights that
# (i)   Had an arrival delay of two or more hours(“arr_delay” variable is measured in minutes)

fl[fl["arr_delay"]>=120]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 119     2013      1    1     811.0             630      101.0    1047.0
# 151     2013      1    1     848.0            1835      853.0    1001.0
# 218     2013      1    1     957.0             733      144.0    1056.0
# 268     2013      1    1    1114.0             900      134.0    1447.0
# 447     2013      1    1    1505.0            1310      115.0    1638.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336579  2013      9   30    1823.0            1545      158.0    1934.0
# 336668  2013      9   30    1951.0            1649      182.0    2157.0
# 336724  2013      9   30    2053.0            1815      158.0    2310.0
# 336757  2013      9   30    2159.0            1845      194.0    2344.0
# 336763  2013      9   30    2235.0            2001      154.0      59.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 119                830      137.0      MQ    4576  N531MQ    LGA  CLT
# 151               1950      851.0      MQ    3944  N942MQ    JFK  BWI
# 218                853      123.0      UA     856  N534UA    EWR  BOS
# 268               1222      145.0      UA    1086  N76502    LGA  IAH
# 447               1431      127.0      EV    4497  N17984    EWR  RIC
# ...                ...        ...     ...     ...     ...    ...  ...
# 336579            1733      121.0      9E    3459  N916XJ    JFK  BNA
# 336668            1903      174.0      EV    4294  N13988    EWR  SAV
# 336724            2054      136.0      EV    5292  N600QX    EWR  ATL
# 336757            2030      194.0      9E    3320  N906XJ    JFK  BUF
# 336763            2249      130.0      B6    1083  N804JB    JFK  MCO
#
#         air_time  distance  hour  minute             time_hour
# 119        118.0       544     6      30  2013-01-01T11:00:00Z
# 151         41.0       184    18      35  2013-01-01T23:00:00Z
# 218         37.0       200     7      33  2013-01-01T12:00:00Z
# 268        248.0      1416     9       0  2013-01-01T14:00:00Z
# 447         63.0       277    13      10  2013-01-01T18:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336579      95.0       765    15      45  2013-09-30T19:00:00Z
# 336668      95.0       708    16      49  2013-09-30T20:00:00Z
# 336724      91.0       746    18      15  2013-09-30T22:00:00Z
# 336757      50.0       301    18      45  2013-09-30T22:00:00Z
# 336763     123.0       944    20       1  2013-10-01T00:00:00Z
#
# [10200 rows x 19 columns]

# %%
# (ii)  Flew to Houston (IAH or HOU)(“dest" is either “IAH” or “HOU”.)

fl[fl["dest"].str.contains("IAH","HOU")|fl["dest"].str.contains("HOU")]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 32      2013      1    1     623.0             627       -4.0     933.0
# 81      2013      1    1     728.0             732       -4.0    1041.0
# 89      2013      1    1     739.0             739        0.0    1104.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336524  2013      9   30    1729.0            1720        9.0    2001.0
# 336527  2013      9   30    1735.0            1715       20.0    2010.0
# 336618  2013      9   30    1859.0            1859        0.0    2134.0
# 336694  2013      9   30    2015.0            2015        0.0    2244.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 32                 932        1.0      UA     496  N459UA    LGA  IAH
# 81                1038        3.0      UA     473  N488UA    LGA  IAH
# 89                1038       26.0      UA    1479  N37408    EWR  IAH
# ...                ...        ...     ...     ...     ...    ...  ...
# 336524            2010       -9.0      UA     652  N455UA    EWR  IAH
# 336527            2005        5.0      WN    2067  N296WN    EWR  HOU
# 336618            2159      -25.0      UA    1128  N14731    LGA  IAH
# 336694            2307      -23.0      UA    1545  N17730    EWR  IAH
# 336737            2354      -25.0      UA     475  N477UA    EWR  IAH
#
#         air_time  distance  hour  minute             time_hour
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 32         229.0      1416     6      27  2013-01-01T11:00:00Z
# 81         238.0      1416     7      32  2013-01-01T12:00:00Z
# 89         249.0      1400     7      39  2013-01-01T12:00:00Z
# ...          ...       ...   ...     ...                   ...
# 336524     173.0      1400    17      20  2013-09-30T21:00:00Z
# 336527     188.0      1411    17      15  2013-09-30T21:00:00Z
# 336618     180.0      1416    18      59  2013-09-30T22:00:00Z
# 336694     174.0      1400    20      15  2013-10-01T00:00:00Z
# 336737     175.0      1400    21       6  2013-10-01T01:00:00Z
#
# [9313 rows x 19 columns]

# %%
# (iii) Were operated by United or Delta (You also need the dataset “airlines.csv”)
# read file
al = pd.read_csv('../dataFiles/airlines.csv')
al
# Out:
#    carrier                         name
# 0       9E            Endeavor Air Inc.
# 1       AA       American Airlines Inc.
# 2       AS         Alaska Airlines Inc.
# 3       B6              JetBlue Airways
# 4       DL         Delta Air Lines Inc.
# 5       EV     ExpressJet Airlines Inc.
# 6       F9       Frontier Airlines Inc.
# 7       FL  AirTran Airways Corporation
# 8       HA       Hawaiian Airlines Inc.
# 9       MQ                    Envoy Air
# 10      OO        SkyWest Airlines Inc.
# 11      UA        United Air Lines Inc.
# 12      US              US Airways Inc.
# 13      VX               Virgin America
# 14      WN       Southwest Airlines Co.
# 15      YV           Mesa Airlines Inc.

# %%
# operated by United or Delta
air =fl.merge(al, on="carrier")
air[air["carrier"].str.contains("UA")|air["carrier"].str.contains("DL")]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     554.0             558       -4.0     740.0
# 3       2013      1    1     558.0             600       -2.0     924.0
# 4       2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 194134  2013      9   30    1955.0            2000       -5.0    2219.0
# 194135  2013      9   30    1956.0            1825       91.0    2208.0
# 194136  2013      9   30    2041.0            2045       -4.0    2147.0
# 194137  2013      9   30    2050.0            2045        5.0      20.0
# 194138  2013      9   30    2121.0            2100       21.0    2349.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0                  819       11.0      UA    1545  N14228    EWR  IAH
# 1                  830       20.0      UA    1714  N24211    LGA  IAH
# 2                  728       12.0      UA    1696  N39463    EWR  ORD
# 3                  917        7.0      UA     194  N29129    JFK  LAX
# 4                  937      -14.0      UA    1124  N53441    EWR  SFO
# ...                ...        ...     ...     ...     ...    ...  ...
# 194134            2230      -11.0      DL    1147  N992DL    LGA  ATL
# 194135            2121       47.0      DL    1576  N3772H    JFK  SAN
# 194136            2208      -21.0      DL     985  N359NB    JFK  BOS
# 194137              53      -33.0      DL     347  N396DA    JFK  SJU
# 194138              14      -25.0      DL    2363  N193DN    JFK  LAX
#
#         air_time  distance  hour  minute             time_hour  \
# 0          227.0      1400     5      15  2013-01-01T10:00:00Z
# 1          227.0      1416     5      29  2013-01-01T10:00:00Z
# 2          150.0       719     5      58  2013-01-01T10:00:00Z
# 3          345.0      2475     6       0  2013-01-01T11:00:00Z
# 4          361.0      2565     6       0  2013-01-01T11:00:00Z
# ...          ...       ...   ...     ...                   ...
# 194134      99.0       762    20       0  2013-10-01T00:00:00Z
# 194135     292.0      2446    18      25  2013-09-30T22:00:00Z
# 194136      37.0       187    20      45  2013-10-01T00:00:00Z
# 194137     188.0      1598    20      45  2013-10-01T00:00:00Z
# 194138     296.0      2475    21       0  2013-10-01T01:00:00Z
#
#                          name
# 0       United Air Lines Inc.
# 1       United Air Lines Inc.
# 2       United Air Lines Inc.
# 3       United Air Lines Inc.
# 4       United Air Lines Inc.
# ...                       ...
# 194134   Delta Air Lines Inc.
# 194135   Delta Air Lines Inc.
# 194136   Delta Air Lines Inc.
# 194137   Delta Air Lines Inc.
# 194138   Delta Air Lines Inc.
#
# [106775 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
# (c) Sort flights to find
# (i)   the most delayed flights.  (use “dep_delay”)

fl.sort_values(by= 'dep_delay', ascending = False)
fl[["flight", "dep_delay"]]
# Out:
#         flight  dep_delay
# 0         1545        2.0
# 1         1714        4.0
# 2         1141        2.0
# 3          725       -1.0
# 4          461       -6.0
# ...        ...        ...
# 336771    3393        NaN
# 336772    3525        NaN
# 336773    3461        NaN
# 336774    3572        NaN
# 336775    3531        NaN
#
# [336776 rows x 2 columns]

# %%
# (ii)  the fastest flights. (you need to calculate “speed” = “distance”/ “air_time” )

fl["speed"] = fl["distance"]/fl["air_time"]
fl.sort_values(by= 'speed', ascending = False)
fl.head(1)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
#
#    distance  hour  minute             time_hour     speed
# 0      1400     5      15  2013-01-01T10:00:00Z  6.167401

# %%
# operated by United or Delta
air =fl.merge(al, on="carrier")
air[air["carrier"].str.contains("UA")|air["carrier"].str.contains("DL")]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     554.0             558       -4.0     740.0
# 3       2013      1    1     558.0             600       -2.0     924.0
# 4       2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 194134  2013      9   30    1955.0            2000       -5.0    2219.0
# 194135  2013      9   30    1956.0            1825       91.0    2208.0
# 194136  2013      9   30    2041.0            2045       -4.0    2147.0
# 194137  2013      9   30    2050.0            2045        5.0      20.0
# 194138  2013      9   30    2121.0            2100       21.0    2349.0
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0                  819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1                  830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2                  728       12.0      UA  ...   N39463    EWR  ORD    150.0
# 3                  917        7.0      UA  ...   N29129    JFK  LAX    345.0
# 4                  937      -14.0      UA  ...   N53441    EWR  SFO    361.0
# ...                ...        ...     ...  ...      ...    ...  ...      ...
# 194134            2230      -11.0      DL  ...   N992DL    LGA  ATL     99.0
# 194135            2121       47.0      DL  ...   N3772H    JFK  SAN    292.0
# 194136            2208      -21.0      DL  ...   N359NB    JFK  BOS     37.0
# 194137              53      -33.0      DL  ...   N396DA    JFK  SJU    188.0
# 194138              14      -25.0      DL  ...   N193DN    JFK  LAX    296.0
#
#         distance  hour  minute             time_hour     speed  \
# 0           1400     5      15  2013-01-01T10:00:00Z  6.167401
# 1           1416     5      29  2013-01-01T10:00:00Z  6.237885
# 2            719     5      58  2013-01-01T10:00:00Z  4.793333
# 3           2475     6       0  2013-01-01T11:00:00Z  7.173913
# 4           2565     6       0  2013-01-01T11:00:00Z  7.105263
# ...          ...   ...     ...                   ...       ...
# 194134       762    20       0  2013-10-01T00:00:00Z  7.696970
# 194135      2446    18      25  2013-09-30T22:00:00Z  8.376712
# 194136       187    20      45  2013-10-01T00:00:00Z  5.054054
# 194137      1598    20      45  2013-10-01T00:00:00Z  8.500000
# 194138      2475    21       0  2013-10-01T01:00:00Z  8.361486
#
#                          name
# 0       United Air Lines Inc.
# 1       United Air Lines Inc.
# 2       United Air Lines Inc.
# 3       United Air Lines Inc.
# 4       United Air Lines Inc.
# ...                       ...
# 194134   Delta Air Lines Inc.
# 194135   Delta Air Lines Inc.
# 194136   Delta Air Lines Inc.
# 194137   Delta Air Lines Inc.
# 194138   Delta Air Lines Inc.
#
# [106775 rows x 21 columns]

# %%
fl.isnull().any()
# Out:
# year              False
# month             False
# day               False
# dep_time           True
# sched_dep_time    False
# dep_delay          True
# arr_time           True
# sched_arr_time    False
# arr_delay          True
# carrier           False
# flight            False
# tailnum            True
# origin            False
# dest              False
# air_time           True
# distance          False
# hour              False
# minute            False
# time_hour         False
# speed              True
# dtype: bool

# %%
# (c) Sort flights to find
# (i)   the most delayed flights.  (use “dep_delay”)

fl.sort_values(by= 'dep_delay', ascending = False)
fl.head(1)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
#
#    distance  hour  minute             time_hour     speed
# 0      1400     5      15  2013-01-01T10:00:00Z  6.167401

# %%
# (ii)  the fastest flights. (you need to calculate “speed” = “distance”/ “air_time” )

fl["speed"] = fl["distance"]/fl["air_time"]
fl.sort_values(by= 'speed', ascending = False)
fl.head(1)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
#
#    distance  hour  minute             time_hour     speed
# 0      1400     5      15  2013-01-01T10:00:00Z  6.167401

# %%
#(d) Currently dep_time is convenient to look at, but hard to compute with because they’re not really continuous numbers. 
# Convert them to a more convenient representation of number of minutes since midnight.
fl['midn_time'] = (fl['dep_time'] / 100 * 60 + fl['dep_time'] % 100) % 1440
fl.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 0             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 1             830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 2             850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 3            1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 4             837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute             time_hour     speed  midn_time
# 0      1400     5      15  2013-01-01T10:00:00Z  6.167401      327.2
# 1      1416     5      29  2013-01-01T10:00:00Z  6.237885      352.8
# 2      1089     5      40  2013-01-01T10:00:00Z  6.806250      367.2
# 3      1576     5      45  2013-01-01T10:00:00Z  8.612022      370.4
# 4       762     6       0  2013-01-01T11:00:00Z  6.568966      386.4
#
# [5 rows x 21 columns]

# %%
# (e) Which carrier has the worst delays? (find the average “arr_delay” for each carrier)

arr_delay = fl.groupby('carrier', as_index = False)['arr_delay'].mean()
sort_fl = arr_delay.sort_values(by = 'arr_delay', ascending=False)
sort_fl.head(1)
# Out:
#   carrier  arr_delay
# 6      F9  21.920705

# %%
# (f)  Find all destinations that are flown by at least two carriers.
df_carrier = fl.groupby("dest")["carrier"].nunique().reset_index(name="carrier_count")
df_carrier[df_carrier["carrier_count"] > 1]
# Out:
#     dest  carrier_count
# 4    ATL              7
# 5    AUS              6
# 6    AVL              2
# 7    BDL              2
# 8    BGR              2
# ..   ...            ...
# 99   SYR              3
# 100  TPA              7
# 102  TVC              2
# 103  TYS              2
# 104  XNA              2
#
# [76 rows x 2 columns]
